# %% [markdown]
# # Working with complicated dataset

# %% [markdown]
# Your name: Duc Nguyen

# %% [markdown]
# ### Question 1
#
# blast_results: https://raw.githubusercontent.com/csbfx/advpy122-data/master/blast_results.csv
#
# Read in the data from the csv file above. Skip all the comment lines, create a header for the dataframe based on the fields list in the comment line that starts with **# Fields:**. Drop the first column `query acc.ver`. Set the `subject acc.ver` as the index of the dataframe. The last column of the dataframe should be `publications`. Show the first five rows of the resulting dataframe.

# %%
import pandas as pd
from urllib.request import urlopen

blast_url = "https://raw.githubusercontent.com/csbfx/advpy122-data/master/blast_results.csv"

with urlopen(blast_url) as response:
    for raw_line in response:
        line = raw_line.decode("utf-8")
        if "# Fields:" in line:
            fields_line = line.split('",')[0].strip('"')
            fields = fields_line.replace("# Fields: ", "").split(", ")
            break

fields.append("extra")

blast_df = pd.read_csv(blast_url, skiprows=7, names=fields)
blast_df = blast_df.drop(columns=["extra"])

blast_df["bonds"] = pd.to_numeric(
    blast_df["bonds"].astype(str).str.replace(",", "", regex=False).str.strip(),
    errors="coerce"
)
blast_df["publications"] = pd.to_numeric(
    blast_df["publications"].astype(str).str.replace(",", "", regex=False).str.strip(),
    errors="coerce"
)

blast_df = blast_df.drop(columns=["query acc.ver"]).set_index("subject acc.ver")

blast_df.head()
# Out:
#                  % identity  alignment length  mismatches  gap opens  \
# subject acc.ver
# NP_904328.1         100.000               318           0          0
# AGK29621.1           99.686               318           1          0
# YP_220563.1          99.686               318           1          0
# ACM24502.1           99.686               318           1          0
# AHG32084.1           99.371               318           2          0
#
#                  q. start  q. end  s. start  s. end  evalue  bit score  \
# subject acc.ver
# NP_904328.1             1     318         1     318       0        629
# AGK29621.1              1     318         1     318       0        629
# YP_220563.1             1     318         1     318       0        627
# ACM24502.1              1     318         1     318       0        627
# AHG32084.1              1     318         1     318       0        627
#
#                  % positives  bonds  publications
# subject acc.ver
# ...

# %% [markdown]
# ### Question 2
# What is the average number of publications?

# %%
blast_df["publications"].mean()
# Out:
# np.float64(26.989690721649485)

# %% [markdown]
# ### Question 3
# List the `subject acc.ver` that has over 15,000 bonds.

# %%
blast_df.loc[blast_df["bonds"] > 15000].index.tolist()
# Out:
# ['AGK29621.1',
#  'AHG32084.1',
#  '6G2J_H',
#  'YP_002791042.1',
#  'AGK29634.1',
#  '0806162F',
#  'YP_009112408.1',
#  'YP_001876469.1',
#  'YP_009092269.1',
#  'AHG32149.1',
#  'YP_009092074.1',
#  'YP_009450474.1',
#  'YP_004123270.1',
#  'YP_009092073.1',
#  'AHZ60901.1',
#  'YP_004123350.1',
#  'YP_009453754.1',
#  'ADD46492.1',
#  'YP_007025968.1',
#  'YP_009453806.1',
#  'YP_007024956.1',
#  'ASM92364.1',
#  'YP_006073044.1',
#  'ASM92494.1',
#  'ADG95699.1',
#  'YP_004891275.1',
#  'YP_009166014.1',
#  'YP_009538416.1',
#  'YP_009414182.1',
#  'YP_009178854.1',
#  'YP_009414415.1',
#  'YP_009353908.1',
#  'YP_009093743.1',
#  'ABX45285.1',
#  'YP_009414156.1',
#  'YP_009414363.1']

# %% [markdown]
# ### Question 4
# Create a plot that shows the correlation between `% identity` and `% positives`.

# %%
import matplotlib.pyplot as plt

blast_df.plot(kind="scatter", x="% identity", y="% positives", figsize=(7, 5), title="% Identity vs % Positives")
plt.show()

# %% [markdown]
# ### Question  5
# Add a column `Protein source` to the dataframe from Question 1 based on the data in this csv file: https://raw.githubusercontent.com/csbfx/advpy122-data/master/protein_source.csv. Merge the data when the `subject acc.ver` from the dataframe equals to `Protein` in the csv file. Entries without a matching protein will have `NA` as `Protein source`.

# %%
protein_url = "https://raw.githubusercontent.com/csbfx/advpy122-data/master/protein_source.csv"
protein_df = pd.read_csv(protein_url)

blast_df = blast_df.merge(
    protein_df[["Protein", "Source"]],
    left_index=True,
    right_on="Protein",
    how="left"
)

blast_df = blast_df.drop(columns=["Protein"]).rename(columns={"Source": "Protein source"})
blast_df.index.name = "subject acc.ver"

blast_df.head()
# Out:
#                  % identity  alignment length  mismatches  gap opens  \
# subject acc.ver
# 0.0                 100.000               318           0          0
# NaN                  99.686               318           1          0
# 1.0                  99.686               318           1          0
# NaN                  99.686               318           1          0
# NaN                  99.371               318           2          0
#
#                  q. start  q. end  s. start  s. end  evalue  bit score  \
# subject acc.ver
# 0.0                     1     318         1     318       0        629
# NaN                     1     318         1     318       0        629
# 1.0                     1     318         1     318       0        627
# NaN                     1     318         1     318       0        627
# NaN                     1     318         1     318       0        627
#
#                  % positives  bonds  publications Protein source
# subject acc.ver
# ...
